# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Selection feature and create dataset again

# %%
bds = pd.read_csv('datasets/batdongsan_data.csv')
chotot = pd.read_csv('datasets/chotot_data.csv')
tvnd = pd.read_csv('datasets/thuviennhadat_data.csv')

bds_des = pd.read_csv('datasets/batdongsan_describe.csv')
chotot_des = pd.read_csv('datasets/chotot_describe.csv')
tvnd_des = pd.read_csv('datasets/thuviennhadat_describe.csv')

# %%
bds
# Out:
#                    filename               time_scraping  \
# 0     p1-l0_20250320-000509  2025-03-20 01:12:28.292573
# 1    p1-l10_20250320-000536  2025-03-20 01:11:43.272543
# 2    p1-l11_20250320-000536  2025-03-20 01:12:02.653646
# 3    p1-l12_20250320-000509  2025-03-20 01:11:41.136257
# 4    p1-l13_20250320-000536  2025-03-20 01:12:27.070338
# ..                      ...                         ...
# 109   p6-l5_20250320-011409  2025-03-20 01:20:27.803582
# 110   p6-l6_20250320-011409  2025-03-20 01:22:07.126392
# 111   p6-l7_20250320-011409  2025-03-20 01:21:42.053570
# 112   p6-l8_20250320-011409  2025-03-20 01:21:36.247118
# 113   p6-l9_20250320-011409  2025-03-20 01:22:15.944547
#
#                                                   link  count  productId  \
# 0    https://batdongsan.com.vn/cho-thue-nha-tro-pho...     20   42471627
# 1    https://batdongsan.com.vn/cho-thue-nha-tro-pho...     20   41981307
# ...

# %%
bds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   filename                 114 non-null    object
#  1   time_scraping            114 non-null    object
#  2   link                     114 non-null    object
#  3   count                    114 non-null    int64
#  4   productId                114 non-null    int64
#  5   price                    114 non-null    int64
#  6   pricePerM2               114 non-null    float64
#  7   categoryId               114 non-null    int64
#  8   cityCode                 114 non-null    object
#  9   districtId               114 non-null    int64
#  10  streetId                 114 non-null    int64
#  11  wardId                   114 non-null    int64
#  12  projectId                114 non-null    int64
#  13  productType              114 non-null    int64
# ...

# %%
bds_new = bds[['filename', 'link', 'title', 'price', 'area', 'address', 'Ngày đăng', 'Ngày hết hạn', 'describe', 'verified']]

# %%
bds_new
# Out:
#                    filename  \
# 0     p1-l0_20250320-000509
# 1    p1-l10_20250320-000536
# 2    p1-l11_20250320-000536
# 3    p1-l12_20250320-000509
# 4    p1-l13_20250320-000536
# ..                      ...
# 109   p6-l5_20250320-011409
# 110   p6-l6_20250320-011409
# 111   p6-l7_20250320-011409
# 112   p6-l8_20250320-011409
# 113   p6-l9_20250320-011409
#
#                                                   link  \
# 0    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 1    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 2    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 3    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 4    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# ..                                                 ...
# 109  https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 110  https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 111  https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 112  https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# ...

# %%
bds_new.columns = ['merge_file_id', 'link', 'title', 'price', 'area', 'address', 'start_post_day', 'end_post_day', 'describe', 'verified']
bds_new['source_post'] = 'batdongsan'
bds_new = bds_new[['merge_file_id', 'source_post', 'link', 'title', 'price', 'area', 'address', 'start_post_day', 'end_post_day', 'describe', 'verified']]
# Out:
# C:\Users\TY NGOC\AppData\Local\Temp\ipykernel_7916\764906202.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bds_new['source_post'] = 'batdongsan'

# %%
bds_new
# Out:
#               merge_file_id source_post  \
# 0     p1-l0_20250320-000509  batdongsan
# 1    p1-l10_20250320-000536  batdongsan
# 2    p1-l11_20250320-000536  batdongsan
# 3    p1-l12_20250320-000509  batdongsan
# 4    p1-l13_20250320-000536  batdongsan
# ..                      ...         ...
# 109   p6-l5_20250320-011409  batdongsan
# 110   p6-l6_20250320-011409  batdongsan
# 111   p6-l7_20250320-011409  batdongsan
# 112   p6-l8_20250320-011409  batdongsan
# 113   p6-l9_20250320-011409  batdongsan
#
#                                                   link  \
# 0    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 1    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 2    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 3    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 4    https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# ..                                                 ...
# 109  https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# ...

# %%
chotot
# Out:
#                      filename               time_scraping  \
# 0      p1-l11_20250404-155753  2025-04-16 23:30:55.781605
# 1    p135-l14_20250404-172843  2025-04-16 23:30:55.014577
# 2      p30-l2_20250404-160805  2025-04-16 23:30:56.246287
# 3     p141-l7_20250404-172843  2025-04-16 23:30:55.351357
# 4      p1-l15_20250404-155753  2025-04-16 23:29:06.285587
# ..                        ...                         ...
# 740    p97-l7_20250404-160805  2025-04-16 23:27:55.367436
# 741    p97-l8_20250404-160805  2025-04-16 23:28:29.108032
# 742    p98-l7_20250404-160805  2025-04-16 23:28:03.671803
# 743   p99-l14_20250404-160805  2025-04-16 23:27:13.110653
# 744   p99-l18_20250404-160805  2025-04-16 23:30:17.745556
#
#                                                   link  \
# 0    https://www.nhatot.com/thue-phong-tro-quan-5-t...
# 1    https://www.nhatot.com/thue-phong-tro-huyen-nh...
# 2    https://www.nhatot.com/thue-phong-tro-quan-7-t...
# ...

# %%
chotot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   filename             745 non-null    object
#  1   time_scraping        745 non-null    object
#  2   link                 745 non-null    object
#  3   title                745 non-null    object
#  4   address              745 non-null    object
#  5   price                745 non-null    object
#  6   dien_tich            745 non-null    object
#  7   describe             745 non-null    object
#  8   Diện tích            745 non-null    object
#  9   Tình trạng nội thất  542 non-null    object
#  10  Số tiền cọc          372 non-null    object
#  11  Tên đường            2 non-null      float64
# dtypes: float64(1), object(11)
# memory usage: 70.0+ KB

# %%
ct_new = chotot[['filename','link', 'title', 'price', 'dien_tich', 'address', 'describe']]

# %%
ct_new
# Out:
#                      filename  \
# 0      p1-l11_20250404-155753
# 1    p135-l14_20250404-172843
# 2      p30-l2_20250404-160805
# 3     p141-l7_20250404-172843
# 4      p1-l15_20250404-155753
# ..                        ...
# 740    p97-l7_20250404-160805
# 741    p97-l8_20250404-160805
# 742    p98-l7_20250404-160805
# 743   p99-l14_20250404-160805
# 744   p99-l18_20250404-160805
#
#                                                   link  \
# 0    https://www.nhatot.com/thue-phong-tro-quan-5-t...
# 1    https://www.nhatot.com/thue-phong-tro-huyen-nh...
# 2    https://www.nhatot.com/thue-phong-tro-quan-7-t...
# 3    https://www.nhatot.com/thue-phong-tro-quan-11-...
# 4    https://www.nhatot.com/thue-phong-tro-quan-10-...
# ..                                                 ...
# 740  https://www.nhatot.com/thue-phong-tro-quan-10-...
# 741  https://www.nhatot.com/thue-phong-tro-quan-5-t...
# 742  https://www.nhatot.com/thue-phong-tro-quan-1-t...
# ...

# %%
ct_new.columns = ['merge_file_id', 'link', 'title', 'price', 'area', 'address', 'describe']
ct_new['source_post'] = 'chotot'
ct_new = ct_new[['merge_file_id', 'source_post', 'link', 'title', 'price', 'area', 'address', 'describe']]
# Out:
# C:\Users\TY NGOC\AppData\Local\Temp\ipykernel_7916\2128794243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ct_new['source_post'] = 'chotot'

# %%
ct_new
# Out:
#                 merge_file_id source_post  \
# 0      p1-l11_20250404-155753      chotot
# 1    p135-l14_20250404-172843      chotot
# 2      p30-l2_20250404-160805      chotot
# 3     p141-l7_20250404-172843      chotot
# 4      p1-l15_20250404-155753      chotot
# ..                        ...         ...
# 740    p97-l7_20250404-160805      chotot
# 741    p97-l8_20250404-160805      chotot
# 742    p98-l7_20250404-160805      chotot
# 743   p99-l14_20250404-160805      chotot
# 744   p99-l18_20250404-160805      chotot
#
#                                                   link  \
# 0    https://www.nhatot.com/thue-phong-tro-quan-5-t...
# 1    https://www.nhatot.com/thue-phong-tro-huyen-nh...
# 2    https://www.nhatot.com/thue-phong-tro-quan-7-t...
# 3    https://www.nhatot.com/thue-phong-tro-quan-11-...
# 4    https://www.nhatot.com/thue-phong-tro-quan-10-...
# ..                                                 ...
# 740  https://www.nhatot.com/thue-phong-tro-quan-10-...
# ...

# %%
ct_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   merge_file_id  745 non-null    object
#  1   source_post    745 non-null    object
#  2   link           745 non-null    object
#  3   title          745 non-null    object
#  4   price          745 non-null    object
#  5   area           745 non-null    object
#  6   address        745 non-null    object
#  7   describe       745 non-null    object
# dtypes: object(8)
# memory usage: 46.7+ KB

# %%
tvnd
# Out:
#                     filename               time_scraping  \
# 0     p48-l3_20250321-091109  2025-03-21 17:39:27.329032
# 1      p1-l0_20250320-172724  2025-03-21 17:31:15.435999
# 2     p1-l10_20250320-172724  2025-03-21 17:34:25.535761
# 3     p1-l11_20250320-172724  2025-03-21 17:30:26.608409
# 4     p1-l12_20250320-172724  2025-03-21 17:24:47.498206
# ...                      ...                         ...
# 1192  p98-l0_20250321-120549  2025-03-21 17:21:16.183624
# 1193  p98-l1_20250321-120549  2025-03-21 12:41:48.270164
# 1194  p98-l2_20250321-120549  2025-03-21 17:37:26.323008
# 1195  p98-l3_20250321-120549  2025-03-21 17:33:27.275448
# 1196  p98-l4_20250321-120549  2025-03-21 12:42:32.294182
#
#                                                    link  \
# 0     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 1     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 2     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# ...

# %%
tvnd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   filename        1197 non-null   object
#  1   time_scraping   1197 non-null   object
#  2   link            1197 non-null   object
#  3   title           1197 non-null   object
#  4   address         1197 non-null   object
#  5   describe        1197 non-null   object
#  6   imgs            1197 non-null   object
#  7   Mức giá         1197 non-null   object
#  8   Diện tích       1197 non-null   object
#  9   Ngày đăng       1197 non-null   object
#  10  Ngày hết hạn    1197 non-null   object
#  11  Hạng tin        1197 non-null   object
#  12  Mã tin          1197 non-null   int64
#  13  Số phòng WC     201 non-null    object
#  14  Nội thất        89 non-null     object
#  15  Pháp lý         20 non-null     object
#  16  Số phòng ngủ    69 non-null     object
# ...

# %%
tvnd_new = tvnd[['filename', 'link', 'title', 'Mức giá', 'Diện tích', 'address', 'Ngày đăng', 'Ngày hết hạn', 'describe']]

# %%
tvnd_new
# Out:
#                     filename  \
# 0     p48-l3_20250321-091109
# 1      p1-l0_20250320-172724
# 2     p1-l10_20250320-172724
# 3     p1-l11_20250320-172724
# 4     p1-l12_20250320-172724
# ...                      ...
# 1192  p98-l0_20250321-120549
# 1193  p98-l1_20250321-120549
# 1194  p98-l2_20250321-120549
# 1195  p98-l3_20250321-120549
# 1196  p98-l4_20250321-120549
#
#                                                    link  \
# 0     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 1     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 2     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 3     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 4     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# ...                                                 ...
# 1192  https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 1193  https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 1194  https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# ...

# %%
tvnd_new.columns = ['merge_file_id', 'link', 'title', 'price', 'area', 'address', 'start_post_day', 'end_post_day', 'describe']
tvnd_new['source_post'] = 'thuviennhadat'
tvnd_new['verified'] = True
tvnd_new = tvnd_new[['merge_file_id', 'source_post', 'link', 'title', 'price', 'area', 'address', 'start_post_day', 'end_post_day', 'describe', 'verified']]
# Out:
# C:\Users\TY NGOC\AppData\Local\Temp\ipykernel_7916\1376834613.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tvnd_new['source_post'] = 'thuviennhadat'
# C:\Users\TY NGOC\AppData\Local\Temp\ipykernel_7916\1376834613.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tvnd_new['verified'] = True

# %%
tvnd_new
# Out:
#                merge_file_id    source_post  \
# 0     p48-l3_20250321-091109  thuviennhadat
# 1      p1-l0_20250320-172724  thuviennhadat
# 2     p1-l10_20250320-172724  thuviennhadat
# 3     p1-l11_20250320-172724  thuviennhadat
# 4     p1-l12_20250320-172724  thuviennhadat
# ...                      ...            ...
# 1192  p98-l0_20250321-120549  thuviennhadat
# 1193  p98-l1_20250321-120549  thuviennhadat
# 1194  p98-l2_20250321-120549  thuviennhadat
# 1195  p98-l3_20250321-120549  thuviennhadat
# 1196  p98-l4_20250321-120549  thuviennhadat
#
#                                                    link  \
# 0     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 1     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 2     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 3     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# 4     https://thuviennhadat.vn/nha-dat-thue-chi-tiet...
# ...                                                 ...
# ...

# %%
bds_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   source_post     114 non-null    object
#  1   link            114 non-null    object
#  2   title           114 non-null    object
#  3   price           114 non-null    int64
#  4   area            114 non-null    int64
#  5   address         114 non-null    object
#  6   start_post_day  114 non-null    object
#  7   end_post_day    114 non-null    object
#  8   describe        114 non-null    object
#  9   verified        114 non-null    bool
# dtypes: bool(1), int64(2), object(7)
# memory usage: 8.3+ KB

# %%
tvnd_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   source_post     1197 non-null   object
#  1   link            1197 non-null   object
#  2   title           1197 non-null   object
#  3   price           1197 non-null   object
#  4   area            1197 non-null   object
#  5   address         1197 non-null   object
#  6   start_post_day  1197 non-null   object
#  7   end_post_day    1197 non-null   object
#  8   describe        1197 non-null   object
#  9   verified        1197 non-null   bool
# dtypes: bool(1), object(9)
# memory usage: 85.5+ KB

# %%
merge = pd.concat([bds_new, tvnd_new], ignore_index=True)

# %%
merge
# Out:
#                merge_file_id    source_post  \
# 0      p1-l0_20250320-000509     batdongsan
# 1     p1-l10_20250320-000536     batdongsan
# 2     p1-l11_20250320-000536     batdongsan
# 3     p1-l12_20250320-000509     batdongsan
# 4     p1-l13_20250320-000536     batdongsan
# ...                      ...            ...
# 1306  p98-l0_20250321-120549  thuviennhadat
# 1307  p98-l1_20250321-120549  thuviennhadat
# 1308  p98-l2_20250321-120549  thuviennhadat
# 1309  p98-l3_20250321-120549  thuviennhadat
# 1310  p98-l4_20250321-120549  thuviennhadat
#
#                                                    link  \
# 0     https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 1     https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 2     https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 3     https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# 4     https://batdongsan.com.vn/cho-thue-nha-tro-pho...
# ...                                                 ...
# ...

# %%
merge.to_csv('data_verified.csv', index=False)

# %%
ct_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   merge_file_id  745 non-null    object
#  1   source_post    745 non-null    object
#  2   link           745 non-null    object
#  3   title          745 non-null    object
#  4   price          745 non-null    object
#  5   area           745 non-null    object
#  6   address        745 non-null    object
#  7   describe       745 non-null    object
# dtypes: object(8)
# memory usage: 46.7+ KB

# %%
ct_new.to_csv('data_unverified_missing.csv', index=False)

# %% [markdown]
# # Data processing

# %%
df_verified = pd.read_csv('datasets/data_verified_merge_no_drop.csv')

# %%
df_verified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1311 entries, 0 to 1310
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   merge_file_id   1311 non-null   object
#  1   source_post     1311 non-null   object
#  2   link            1311 non-null   object
#  3   title           1311 non-null   object
#  4   price           1311 non-null   object
#  5   area            1311 non-null   object
#  6   address_x       1311 non-null   object
#  7   start_post_day  1311 non-null   object
#  8   end_post_day    1311 non-null   object
#  9   describe        1311 non-null   object
#  10  verified        1311 non-null   bool
#  11  filename        1311 non-null   object
#  12  address_y       1311 non-null   object
#  13  Tỉnh/Thành phố  1311 non-null   object
#  14  Quận/Huyện      1311 non-null   object
#  15  Phường/Xã       1310 non-null   object
#  16  Tên đường       109 non-null    object
# ...

# %%
df_verified.drop(columns=['Ghi chú', 'filename', 'address_x', 'Unnamed: 0'], inplace=True)

# %%
df_verified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1311 entries, 0 to 1310
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   merge_file_id   1311 non-null   object
#  1   source_post     1311 non-null   object
#  2   link            1311 non-null   object
#  3   title           1311 non-null   object
#  4   price           1311 non-null   object
#  5   area            1311 non-null   object
#  6   start_post_day  1311 non-null   object
#  7   end_post_day    1311 non-null   object
#  8   describe        1311 non-null   object
#  9   verified        1311 non-null   bool
#  10  address_y       1311 non-null   object
#  11  Tỉnh/Thành phố  1311 non-null   object
#  12  Quận/Huyện      1311 non-null   object
#  13  Phường/Xã       1310 non-null   object
#  14  Tên đường       109 non-null    object
#  15  Số nhà          1017 non-null   object
# dtypes: bool(1), object(15)
# memory usage: 155.0+ KB

# %%
df_verified.columns
# Out:
# Index(['merge_file_id', 'source_post', 'link', 'title', 'price', 'area',
#        'start_post_day', 'end_post_day', 'describe', 'verified', 'address_y',
#        'Tỉnh/Thành phố', 'Quận/Huyện', 'Phường/Xã', 'Tên đường', 'Số nhà'],
#       dtype='object')

# %%
df_verified.columns = [
    'merge_file_id', 'source_post', 'link', 'title', 'price', 'area',
    'start_post_day', 'end_post_day', 'describe', 'verified', 'address',
    'province/city', 'district', 'ward', 'street', 'house_number'
]

# %%
df_verified.to_csv('verified_data.csv', index=False)
